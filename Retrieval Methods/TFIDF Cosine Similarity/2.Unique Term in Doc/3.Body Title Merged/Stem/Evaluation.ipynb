# %% [markdown]
# # Setup

# %%
url = 'http://ee64-34-125-38-181.ngrok.io'
# url = 'http://35.232.59.3:8080'

# %%
from tqdm import tqdm
import matplotlib.pyplot as plt
from zipfile import ZipFile
# %matplotlib inline

# %% [markdown]
# # Evaluation Functions

# %%
def recall_at_k(true_list,predicted_list,k=40):   
      
    return round(len([i for i in predicted_list[:k] if i in true_list]) / len(true_list), 3)

# %%
def precision_at_k(true_list,predicted_list,k=40):     

    return round(len([i for i in predicted_list[:k] if i in true_list]) / k, 3)

# %%
def r_precision(true_list,predicted_list):

    return round(len([i for i in predicted_list[:len(true_list)] if i in true_list]) / len(true_list), 3)

# %%
def reciprocal_rank_at_k(true_list,predicted_list,k=40):

    ele = next((i for i, v in enumerate(predicted_list) if v in true_list), None)
    if ele == None or ele > (k - 1):
      return 0.000
    else:
      return round(1 / (ele + 1), 3)

# %%
def f_score(true_list,predicted_list,k=40):
    
    precision = precision_at_k(true_list,predicted_list,k)
    recall = recall_at_k(true_list,predicted_list,k)
    if precision == 0 and recall == 0:
      return 0
    else:
      return round((2 * precision * recall) / (precision + recall), 3)

# %%
def average_precision(true_list, predicted_list, k=40):
    true_set = frozenset(true_list)
    predicted_list = predicted_list[:k]
    precisions = []
    for i,doc_id in enumerate(predicted_list):        
        if doc_id in true_set:
            prec = (len(precisions)+1) / (i+1)            
            precisions.append(prec)
    if len(precisions) == 0:
        return 0.0
    return round(sum(precisions)/len(precisions),3)

# %%
def evaluate(true_relevancy,predicted_relevancy,k,print_scores=True):   

    recall_lst = []
    precision_lst = []
    f_score_lst = []
    r_precision_lst = []
    reciprocal_rank_lst = []
    avg_precision_lst = []
    metrices = {'recall@k':recall_lst,
                'precision@k':precision_lst,
                'f_score@k': f_score_lst,
                'r-precision': r_precision_lst,
                'MRR@k':reciprocal_rank_lst,
                'MAP@k':avg_precision_lst}

    for query, ground_true in true_relevancy:  
      predicted = predicted_relevancy[query]

      recall_lst.append(recall_at_k(ground_true,predicted,k=k))
      precision_lst.append(precision_at_k(ground_true,predicted,k=k))
      f_score_lst.append(f_score(ground_true,predicted,k=k))
      r_precision_lst.append(r_precision(ground_true,predicted))
      reciprocal_rank_lst.append(reciprocal_rank_at_k(ground_true,predicted,k=k))
      avg_precision_lst.append(average_precision(ground_true,predicted,k=k))

    if print_scores:
        for name,values in metrices.items():
                print(name,sum(values)/len(values))

    return metrices

# %%
def plot_metric_different_quieries(true_relevancy,predicted_relevancy,metrices_names,k):

    for metric_name in metrices_names:
      met = evaluate(true_relevancy,predicted_relevancy,k=k,print_scores=False)
      met_list = met[metric_name]
      plt.xlabel("Queries")
      plt.ylabel("Metric")
      plt.title(metric_name)
      plt.plot([i+1 for i in range(len(met_list))], met_list)
      plt.show()

# %% [markdown]
# # Test PageRank and PageViews

# %%
import requests
from time import time

try:
  res = requests.post(url + '/get_pageview', json=[1, 3434750, 713, 1], timeout=35)
  if res.status_code == 200:
    pred_wids = res.json()
    print(pred_wids)
except:
  pass

try:
  res = requests.post(url + '/get_pagerank', json=[1, 3434750, 713, 1], timeout=35)
  if res.status_code == 200:
    pred_wids = res.json()
    print(pred_wids)
except:
  pass
# Out:
# [1559062, 14347]
# [9913.72878216078, 13.387949399744079]

# %% [markdown]
# # Test all queries with MAP

# %%
import json

with open('queries_train.json', 'rt') as f:
  queries = json.load(f)

# %%
import pickle

with open("dt/dt.pkl", 'rb') as f:
    dt = pickle.load(f)

# %%
a = {k:[(id,dt.get(id, 'None')) for id in v] for k, v in queries.items()}

# %%
print(a['data science'])
#print(len([t for id, t in a['data science'] if (('data' in t or 'Data' in t) and ('Science' in t or 'science' in t))]))
# Out:
# [(35458904, 'Data science'), (2720954, 'Data analysis'), (54415758, 'Master in Data Science'), (233488, 'Machine learning'), (12487489, 'Data wrangling'), (48364486, 'Berkeley Institute for Data Science'), (487132, 'Analytics'), (416589, 'Exploratory data analysis'), (27051151, 'Big data'), (66414222, 'Data Science and Predictive Analytics'), (18985040, 'Data'), (4141563, 'Predictive analytics'), (376707, 'R (programming language)'), (67092078, 'Women in Data Science Initiative'), (61624594, 'The Center of Applied Data Science'), (59591015, 'Faculty (company)'), (49681, 'Ontology (information science)'), (55052729, 'New York University Center for Data Science'), (31663650, 'Kaggle'), (35757264, 'Prescriptive analytics'), (63995662, 'ODSC'), (3461736, 'Data visualization'), (56499662, 'Data science competition platform'), (43003632, 'Anaconda (Python distribution)'), (26685, 'Statistics'), (10147369, 'Business analytics'), (24932989, 'Data analysis techniques for fraud detection'), (66982525, 'David Shor'), (5323, 'Computer science'), (46207323, 'Feature engineering'), (8495, 'Data set'), (31915311, 'Open science data'), (51552534, 'Data activism'), (64057049, 'Rebekah Jones'), (45443335, 'DJ Patil'), (37849704, 'Usama Fayyad'), (42149032, 'Alpine Data Labs'), (63198823, 'David G. Robinson (data scientist)'), (38833779, 'Pandas (software)'), (26880450, 'C. F. Jeff Wu'), (39171985, 'Eureqa'), (5213, 'Computing'), (44133735, 'Alteryx'), (28486111, 'Learning analytics'), (48972018, 'Hilary Mason (data scientist)'), (23943140, 'Data curation'), (17740009, 'Topological data analysis'), (49954680, 'Data Science Institute'), (28326718, 'Astroinformatics'), (63016369, 'Cha Meeyoung'), (56023027, 'List of scientific misconduct incidents'), (58731, 'Peter Naur'), (55207134, 'IBM Watson Studio'), (62798611, 'Cassie Kozyrkov'), (65732625, 'Owl Scientific Computing'), (58255666, 'Computational psychometrics'), (68181697, 'International Journal of Population Data Science'), (47892671, 'Gregory Piatetsky-Shapiro'), (1309220, 'Imputation (statistics)'), (65499427, 'Santanu Bhattacharya (data scientist)'), (58255600, 'FAIR data'), (47638279, 'Data Analytics Acceleration Library'), (46626475, 'Data lake'), (46374359, 'William S. Cleveland'), (53343108, 'Dan Wagner (data scientist)'), (173332, 'Overfitting'), (7671, 'Committee on Data for Science and Technology'), (18745015, 'Fractal analysis'), (50565707, 'Continuous analytics'), (57143357, 'Glossary of computer science'), (45112545, 'Looker (company)'), (63148404, 'Ilkay Altintas'), (50533783, 'Datascope Analytics'), (51112472, 'Dataiku'), (49281083, 'The Data Incubator'), (51505979, 'Master of Science in Business Analytics'), (1181008, 'Computational science'), (56731447, 'The Fourth Paradigm'), (59116880, 'Rumman Chowdhury'), (51578025, 'Critical data studies'), (21462612, 'Profiling (information science)'), (1765779, 'Data cube'), (39675445, 'Data literacy'), (42253, 'Data mining')]

# %%
token = 'data science'
o = [(id, dt[id]) for id in pred_wids[token] if id not in [id for id, t in a[token]]] # חזרו ולא רלוונטים
b = [(id, t) for id, t in a[token] if id in pred_wids[token]] # רלוונטים שחזרו
c = [(id, t) for id, t in a[token] if id not in pred_wids[token]] # רלוונטים שלא חזרו
selected = o
print(len(selected))
print(selected)
# Out:
# 3
# [(2155752, 'Citizen science'), (33055919, 'Visa policy of Uzbekistan'), (41459258, 'List of Woking F.C. seasons')]

# %%
import requests
from time import time
url = 'http://b0c7-35-196-170-248.ngrok.io'
qs_res = []
pred_wids = {}
sum_duration = 0
map25 = True
duration35 = True
for q, true_wids in queries.items():
  duration, ap = None, None
  t_start = time()
  try:
    res = requests.get(url + '/search', {'query': q}, timeout=35)
    duration = time() - t_start
    sum_duration += duration
    if res.status_code == 200:
      pred_wids[q] = [tup[0] for tup in res.json()]
      ap = average_precision(true_wids, pred_wids[q])
      if ap < 0.25: map25 = False 
  except:
    pass
  
  if duration == None: duration35 = False
  qs_res.append((q, duration, ap))

# %%
print("Duration < 35s : " + str(duration35))
print("AP@40 > 0.25   : " + str(map25))
print("AVG Duration   : " + str(sum_duration/len(queries)) + "\n")
qs_res
# Out:
# Duration < 35s : True
# AP@40 > 0.25   : False
# AVG Duration   : 2.0164058526357014
# [('python', 0.12825989723205566, 0.699),
#  ('data science', 20.519531965255737, 0.708),
#  ('migraine', 0.09462761878967285, 0.963),
#  ('chocolate', 0.13250398635864258, 0.614),
#  ('how to make pasta', 1.324009656906128, 0.626),
#  ('Does pasta have preservatives?', 0.5393786430358887, 0.157),
#  ('how google works', 5.077178716659546, 0.777),
#  ('what is information retrieval', 2.051893949508667, 0.87),
#  ('NBA', 0.15926909446716309, 0.429),
#  ('yoga', 0.10919189453125, 0.548),
#  ('how to not kill plants', 7.108787298202515, 0.682),
#  ('masks', 0.2064499855041504, 0.678),
#  ('black friday', 3.048168420791626, 0.932),
#  ('why do men have nipples', 0.9805667400360107, 0.754),
#  ('rubber duck', 0.18686151504516602, 0.826),
#  ('michelin', 0.10439491271972656, 0.446),
#  ('what to watch', 0.44527268409729004, 0.5),
#  ('best marvel movie', 2.0926365852355957, 0.639),
#  ('how tall is the eiffel tower', 1.9762427806854248, 0.81),
#  ('where does vanilla flavoring come from', 1.1550712585449219, 0.811),
#  ('best ice cream flavour', 2.3978073596954346, 0.636),
#  ('how to tie a tie', 0.47921252250671387, 0.809),
#  ('how to earn money online', 1.2861485481262207, 0.279),
#  ('what is critical race theory', 2.560102939605713, 0.55),
#  ('what space movie was made in 1992', 3.4414639472961426, 0.36),
#  ('how to vote', 0.6771337985992432, 0.496),
#  ('google trends', 0.25260186195373535, 0.683),
#  ('dim sum', 0.18682646751403809, 0.923),
#  ('ted', 0.21598291397094727, 0.521),
#  ('fairy tale', 1.5545976161956787, 0.592)]

# %%
evaluate(queries.items(),pred_wids,k=40,print_scores=True)
plot_metric_different_quieries(queries.items(),pred_wids,['precision@k','recall@k','f_score@k','r-precision','MRR@k','MAP@k'],k=40)
# Out:
# recall@k 0.21359999999999996
# precision@k 0.42916666666666675
# f_score@k 0.2838333333333333
# r-precision 0.3047666666666667
# MRR@k 0.7983333333333333
# MAP@k 0.6439333333333332
